# %%
import requests
import pandas as pd
import csv

file = "Food_Environment_Atlas_Health.csv"
food_atlas_health = pd.read_csv(file, encoding = "ISO-8859-1")

file2 = "Food_Environment_Atlas_Access.csv"
food_atlas_access = pd.read_csv(file2, encoding = "ISO-8859-1")

# %%
#food_atlas_health = food_atlas_health.set_index("State")

food_atlas_health = food_atlas_health.loc[food_atlas_health["State"] == "IL", :]
food_atlas_health.rename(columns={"PCT_DIABETES_ADULTS08":"Adult Diabetes Rate (2008)", "PCT_DIABETES_ADULTS13":"Adult diabetes rate (2013)", "PCT_OBESE_ADULTS08":"Adult obesity rate (2008)", "PCT_OBESE_ADULTS13":"Adult obesity rate (2013)",
                                 "PCT_HSPA15":"High schoolers physically active (%), 2015", "RECFAC09":"Recreation & fitness facilities (2009)","RECFAC14":"Recreation & fitness facilities (2014)", "PCH_RECFAC_09_14":"Recreation & fitness facilities (% change), 2009-14",
                                  "RECFACPTH09":"Recreation & fitness facilities/1,000 pop (2009)", "RECFACPTH14":"Recreation & fitness facilities/1,000 pop (2014)",
                                  "PCH_RECFACPTH_09_14":"Recreation & fitness facilities/1,000 pop (% change), 2009-14"
                                   }, inplace=True)

# %%
food_atlas_health
# Out:
#       FIPS State      County  Adult Diabetes Rate (2008)  \
# 595  17001    IL       Adams                         9.0
# 596  17003    IL   Alexander                        11.0
# 597  17005    IL        Bond                         8.8
# 598  17007    IL       Boone                         7.2
# 599  17009    IL       Brown                         7.9
# ..     ...   ...         ...                         ...
# 692  17195    IL   Whiteside                         8.9
# 693  17197    IL        Will                         7.9
# 694  17199    IL  Williamson                         8.7
# 695  17201    IL   Winnebago                         9.2
# 696  17203    IL    Woodford                         8.4
#
#      Adult diabetes rate (2013)  Adult obesity rate (2008)  \
# 595                        10.1                       26.5
# 596                        11.4                       28.2
# 597                        10.0                       27.9
# ...

# %%
food_atlas_access = food_atlas_access.loc[food_atlas_access["State"] == "IL", :]
food_atlas_access
# Out:
#       FIPS State      County  LACCESS_POP10  LACCESS_POP15  \
# 595  17001    IL       Adams   10505.232660   10346.464750
# 596  17003    IL   Alexander    3858.855610    1748.049110
# 597  17005    IL        Bond    2080.987933    1281.433552
# 598  17007    IL       Boone    9063.970399   11409.517780
# 599  17009    IL       Brown    1910.444209    1662.659777
# ..     ...   ...         ...            ...            ...
# 692  17195    IL   Whiteside    9949.308567   13051.789530
# 693  17197    IL        Will  242455.252500  217703.442300
# 694  17199    IL  Williamson   11942.924020    9594.145863
# 695  17201    IL   Winnebago   72887.044310   76322.412930
# 696  17203    IL    Woodford    2900.696181    4535.317178
#
#      PCH_LACCESS_POP_10_15  PCT_LACCESS_POP10  PCT_LACCESS_POP15  \
# 595              -1.511322          15.655385          15.418781
# 596             -54.700323          46.842141          21.219339
# ...

# %%
food_atlas_access.rename(columns={"LACCESS_POP10":"Population, low access to store (2010)","LACCESS_POP15":"Population, low access to store (2015)","PCH_LACCESS_POP_10_15":"Population, low access to store (% change), 2010 -15",
                                  "PCT_LACCESS_POP10":"Population, low access to store (%), 2010","PCT_LACCESS_POP15":"Population, low access to store (%), 2015",
                                  "LACCESS_LOWI10":"Low income & low access to store, 2010","LACCESS_LOWI15":"Low income & low access to store, 2015","LACCESS_HISP15":"Hispanic ethnicity, low access to store, 2015",
                                  "PCT_LACCESS_HISP15":"Hispanic ethnicity, low access to store (%), 2015","LACCESS_NHASIAN15":"Asian, low access to store, 2015",
                                  "PCT_LACCESS_NHASIAN15":"Asian, low access to store (%), 2015", "LACCESS_NHNA15":"American Indian or Alaska Native, low access to store, 2015",
                                  "PCT_LACCESS_NHNA15":"American Indian or Alaska Native, low access to store (%), 2015", "LACCESS_NHPI15":"Hawaiian or Pacific Islander, low access to store, 2015",
                                  "PCT_LACCESS_NHPI15":"Hawaiian or Pacific Islander, low access to store (%), 2015","LACCESS_MULTIR15":"Multiracial, low access to store, 2015", "PCT_LACCESS_MULTIR15":"Multiracial, low access to store (%), 2015"
                                    }, inplace = True)

# %%
food_atlas_access
# Out:
#       FIPS State      County  Population, low access to store (2010)  \
# 595  17001    IL       Adams                            10505.232660
# 596  17003    IL   Alexander                             3858.855610
# 597  17005    IL        Bond                             2080.987933
# 598  17007    IL       Boone                             9063.970399
# 599  17009    IL       Brown                             1910.444209
# ..     ...   ...         ...                                     ...
# 692  17195    IL   Whiteside                             9949.308567
# 693  17197    IL        Will                           242455.252500
# 694  17199    IL  Williamson                            11942.924020
# 695  17201    IL   Winnebago                            72887.044310
# 696  17203    IL    Woodford                             2900.696181
#
#      Population, low access to store (2015)  \
# 595                            10346.464750
# 596                             1748.049110
# ...
